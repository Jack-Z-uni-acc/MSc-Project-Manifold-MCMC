# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 1000 # Number of iterations to run RWMH for each parameter value
n = 100 # Number of dimensions to test over
seed = 0 # Seed for random number generator
X0 = 0 # Initial value for all tests

# %%
def V(x):
  return -np.linalg.norm(x)

# %%
# pCN Log-acceptance probability
def log_r(x, y):
  return V(x)-V(y)

# %%
# pCN step
def step(x, beta, xi, U):

  px = np.sqrt(1 - beta**2) * x + beta * xi
  acc = min(0,log_r(x, px))

  if acc < U:
    y = x
    success = 0

  else:
    y = px
    success = 1

  return y, acc, success

# %%
# Scaling with fixed beta = 1
beta = 0.3
E_log_r = np.zeros(n)
E_alpha = np.zeros(n)

for i in range(n):

  np.random.seed(seed + i)
  xis = np.random.normal(size=(m,i))
  Us = np.log(np.random.uniform(0,1,m))

  rval = 0
  sval = 0
  x = X0

  for j in range(m):

    x, r, s = step(x, beta, xis[j], Us[j])
    rval += r
    sval += s

  rval /= m
  sval /= m
  E_log_r[i] = rval
  E_alpha[i] = sval

# %%
fig, ax = plt.subplots()
xvals = np.arange(0,n)
ax.plot(xvals,E_log_r,label='$E[logr]$')
ax.plot(xvals,-xvals/2,'--',label='y = -0.5*beta^2*N')
ax.set_title('$E[logr]$ at fixed beta = 0.3.')
ax.set_ylabel('$E[logr]$')
ax.set_xlabel('$N$')
ax.grid()
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(xvals[:50],E_alpha[:50],label='$E[alpha]$')
ax.plot(xvals[:50], np.exp(-0.2*xvals[:50]),'--',label='y = exp(-0.03*N)')
ax.set_title('$E[alpha]$ at fixed beta = 0.3.')
ax.set_ylabel('$E[alpha]$')
ax.set_xlabel('$N$')
ax.legend()
ax.grid()
plt.show()
